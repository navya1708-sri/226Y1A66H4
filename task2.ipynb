# %% [markdown]
# <a href="https://colab.research.google.com/github/navya1708-sri/226Y1A66H4/blob/main/task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from fpdf import FPDF

# !pip install fpdf

pdf = FPDF()
pdf.add_page()
pdf.set_font("Arial", size=12)

pdf.cell(200, 10, txt="Invoice No: INV12345", ln=True)
pdf.cell(200, 10, txt="Date: 23/01/2026", ln=True)
pdf.cell(200, 10, txt="Item    Qty    Price", ln=True)
pdf.cell(200, 10, txt="Laptop  1      75000", ln=True)
pdf.cell(200, 10, txt="Mouse   2      1500", ln=True)
pdf.cell(200, 10, txt="Total: 78000", ln=True)

pdf.output("sample_invoice.pdf")

print("Sample invoice created: sample_invoice.pdf")
# Out:
# ...
# Sample invoice created: sample_invoice.pdf

# %%
# !pip install fpdf
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=288dbb0f6cbec3f51f99a795f169c1b8df4f0ebec7f9c07aa03b3c675967e197
#   Stored in directory: /root/.cache/pip/wheels/6e/62/11/dc73d78e40a218ad52e7451f30166e94491be013a7850b5d75
# Successfully built fpdf
# ...

# %%
from fpdf import FPDF

# %%
sample_text = """
Invoice No: INV12345
Date: 23/01/2026
Item    Qty    Price
Laptop  1      75000
Mouse   2      1500
Total: 78000
"""

parsed = parse_invoice_text([sample_text])
print(parsed)
# Out:
# {'InvoiceNumber': 'INV12345', 'Date': '23/01/2026', 'Total': '78000', 'LineItems': 'Laptop  1      75000; Mouse   2      1500'}

# %%
import pandas as pd

parsed = {
  'InvoiceNumber': 'INV12345',
  'Date': '23/01/2026',
  'Total': '78000',
  'LineItems': 'Laptop  1      75000; Mouse   2      1500'
}

df = pd.DataFrame([parsed])
df.to_csv("extracted_invoices.csv", index=False)
print("CSV created: extracted_invoices.csv")
df.head()
# Out:
# CSV created: extracted_invoices.csv
#   InvoiceNumber        Date  Total                                  LineItems
# 0      INV12345  23/01/2026  78000  Laptop  1      75000; Mouse   2      1500

# %%
line_items = [
    {"Item": "Laptop", "Qty": 1, "Price": 75000},
    {"Item": "Mouse", "Qty": 2, "Price": 1500}
]

items_df = pd.DataFrame(line_items)
print(items_df)
# Out:
#      Item  Qty  Price
# 0  Laptop    1  75000
# 1   Mouse    2   1500

# %%
invoice_meta = {"InvoiceNumber": "INV12345", "Date": "23/01/2026", "Total": 78000}
items_df["InvoiceNumber"] = invoice_meta["InvoiceNumber"]

final_df = items_df[["InvoiceNumber", "Item", "Qty", "Price"]]
print(final_df)
# Out:
#   InvoiceNumber    Item  Qty  Price
# 0      INV12345  Laptop    1  75000
# 1      INV12345   Mouse    2   1500

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-57a19a6e-5810-4e5a-b67d-3f08d9c1e4ca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-57a19a6e-5810-4e5a-b67d-3f08d9c1e4ca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from fpdf import FPDF

# !pip install fpdf

pdf = FPDF()
pdf.add_page()
pdf.set_font("Arial", size=12)

pdf.cell(200, 10, txt="Invoice No: INV12345", ln=True)
pdf.cell(200, 10, txt="Date: 23/01/2026", ln=True)
pdf.cell(200, 10, txt="Item    Qty    Price", ln=True)
pdf.cell(200, 10, txt="Laptop  1      75000", ln=True)
pdf.cell(200, 10, txt="Mouse   2      1500", ln=True)
pdf.cell(200, 10, txt="Total: 78000", ln=True)

pdf.output("sample_invoice.pdf")
print("Sample invoice created: sample_invoice.pdf")
# Out:
# ...
# Sample invoice created: sample_invoice.pdf

# %%
def process_pdfs(pdf_folder):
    records = []
    for filename in os.listdir(pdf_folder):
        if filename.lower().endswith(".pdf"):
            pdf_path = os.path.join(pdf_folder, filename)
            text_pages = extract_text_from_pdf(pdf_path)
            parsed = parse_invoice_text(text_pages)
            parsed["FileName"] = filename
            records.append(parsed)
    return records

records = process_pdfs("/content")

# %%
def process_pdfs(pdf_files):
    records = []
    for pdf in pdf_files:
        text_pages = extract_text_from_pdf(pdf)
        parsed = parse_invoice_text(text_pages)
        parsed["FileName"] = pdf
        records.append(parsed)
    return records

pdf_files = ["sample_invoice.pdf"]
records = process_pdfs(pdf_files)

# %%
pdf_files = ["sample_invoice.pdf"]
records = process_pdfs(pdf_files)
df = pd.DataFrame(records)
df.to_csv("extracted_invoices.csv", index=False)
df.head()
# Out:
#   InvoiceNumber        Date  Total                     LineItems  \
# 0      INV12345  23/01/2026  78000  Laptop 1 75000; Mouse 2 1500
#
#              FileName
# 0  sample_invoice.pdf
